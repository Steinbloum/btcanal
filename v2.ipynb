# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px
from datetime import datetime
import glob

# %%
def get_df (csvfile):
    df = pd.read_csv(csvfile)
    df.columns = [
    "date",
    "open",
    "high",
    "low",
    "close",
    "RL",
    "closetime",
    "ignore1",
    "ignore2",
    "ignore3",
    "ignore4",
    "ignore5",
    ]
    df = pd.DataFrame(df, columns=["date", "open", "high", "low", "close"])
    lsnumday = []
    lsweekday = []
    lsvar = []
    lst = []
    dictdays = {
        0: "Monday",
        1: "Tuesday",
        2: "Wednesday",
        3: "Thursday",
        4: "Friday",
        5: "Saturday",
        6: "Sunday",
    }
    for n in range(len(df)):
        ts = df.iloc[n, 0] / 1000
        dt = datetime.fromtimestamp(ts)
        df.iloc[n, 0] = dt
        weekd = datetime.weekday(df.iloc[n, 0])
        lsnumday.append(weekd)
        var = df.iloc[n, 4] / df.iloc[n, 1] * 100 - 100
        lsvar.append(var)
    for item in lsnumday:
        lsweekday.append(dictdays[item])
    df["weekday"] = lsweekday
    df["variation"] = lsvar
    for n in range(len(df)):
        dtm = df.iloc[n, 0]
        tm = dtm.time()
        lst.append(tm)
    df["opentime"] = lst
    return df

# %%
df1 = get_df("Klines1hbtcusdtraw/BTCUSDT-1h-2020-01.csv")
df2 = get_df("Klines1hbtcusdtraw/BTCUSDT-1h-2020-02.csv")
df1
df1 = df1.append(df2, ignore_index = True)
df1
# Out:
#                      date     open     high      low    close    weekday  \
# 0     2020-01-01 02:00:00  7171.43  7225.00  7171.10  7210.24  Wednesday
# 1     2020-01-01 03:00:00  7210.38  7239.30  7206.46  7237.99  Wednesday
# 2     2020-01-01 04:00:00  7237.41  7239.74  7215.00  7221.65  Wednesday
# 3     2020-01-01 05:00:00  7221.80  7225.41  7211.22  7213.86  Wednesday
# 4     2020-01-01 06:00:00  7213.86  7224.09  7213.86  7220.31  Wednesday
# ...                   ...      ...      ...      ...      ...        ...
# 1433  2020-02-29 20:00:00  8672.59  8683.00  8641.05  8680.00   Saturday
# 1434  2020-02-29 21:00:00  8679.89  8679.89  8650.00  8664.13   Saturday
# 1435  2020-02-29 22:00:00  8664.01  8671.41  8620.00  8641.88   Saturday
# 1436  2020-02-29 23:00:00  8642.03  8645.93  8603.00  8643.30   Saturday
# 1437  2020-03-01 00:00:00  8643.30  8666.66  8530.00  8531.98     Sunday
#
#       variation  opentime
# 0      0.541175  02:00:00
# 1      0.382920  03:00:00
# 2     -0.217757  04:00:00
# 3     -0.109945  05:00:00
# 4      0.089411  06:00:00
# ...         ...       ...
# 1433   0.085442  20:00:00
# 1434  -0.181569  21:00:00
# 1435  -0.255424  22:00:00
# 1436   0.014696  23:00:00
# 1437  -1.287934  00:00:00
#
# [1438 rows x 8 columns]

# %% [markdown]
# Fonction pour regrouper tout en 1 DF

# %%
def group_df(folder):
    path = folder
    all_files = glob.glob(path + "/*.csv")
    print(all_files)
    n=0
    df = pd.DataFrame()
    for file in all_files:
        if n == 0:
            df = get_df(file)
            df
            n+=1
        else:
            df2 = get_df(file)
            df = df.append(df2, ignore_index=True)
            
    return df

df = group_df("Klines1hbtcusdtraw")
# Out:
# ['Klines1hbtcusdtraw/BTCUSDT-1h-2021-05.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-02.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-12.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-08.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-10.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-01.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-06.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-09.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-05.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-07.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-03.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-08.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-02.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-07.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-10.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-04.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-03.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2021-01.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-04.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-09.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-06.csv', 'Klines1hbtcusdtraw/BTCUSDT-1h-2020-11.csv']

# %%
df
# Out:
#                       date      open      high       low     close   weekday  \
# 0      2021-05-01 03:00:00  57820.59  58488.17  57500.50  58444.58  Saturday
# 1      2021-05-01 04:00:00  58443.51  58454.76  57966.00  58128.66  Saturday
# 2      2021-05-01 05:00:00  58128.66  58274.93  58059.38  58206.90  Saturday
# 3      2021-05-01 06:00:00  58206.89  58277.11  57720.00  58100.65  Saturday
# 4      2021-05-01 07:00:00  58100.27  58461.81  57940.62  58183.60  Saturday
# ...                    ...       ...       ...       ...       ...       ...
# 16053  2020-11-30 20:00:00  19201.40  19337.39  19108.89  19275.44    Monday
# 16054  2020-11-30 21:00:00  19273.92  19506.50  19185.00  19446.45    Monday
# 16055  2020-11-30 22:00:00  19446.45  19550.00  19334.01  19390.00    Monday
# 16056  2020-11-30 23:00:00  19390.00  19519.57  19258.30  19519.56    Monday
# 16057  2020-12-01 00:00:00  19519.57  19775.34  19461.31  19720.00   Tuesday
#
#        variation  opentime
# 0       1.079183  03:00:00
# 1      -0.538725  04:00:00
# 2       0.134598  05:00:00
# 3      -0.182521  06:00:00
# 4       0.143424  07:00:00
# ...          ...       ...
# 16053   0.385597  20:00:00
# 16054   0.895147  21:00:00
# 16055  -0.290284  22:00:00
# 16056   0.668179  23:00:00
# 16057   1.026816  00:00:00
#
# [16058 rows x 8 columns]

# %%
def gather_info(df):

    df2 = pd.DataFrame(columns= ["weekday", "opentime", "mean", "med", "ratio"])
    lsweekday = df.weekday.unique().tolist()
    lshours = df.opentime.unique().tolist()
    dicta = {}
    for day in lsweekday:
        for hour in lshours:
            ls = []
            pos = 0
            neg = 0
            for n in range(len(df)):
                if df.iloc[n, 5] == day and df.iloc[n, 7] == hour :
                    var = df.iloc[n, 6]
                    print("found")
                    ls.append(var)
                    if var >= 0:
                        pos += 1
                    else:
                        neg +=1
            mean = np.mean(ls)
            med = np.median(ls)
            ratio = (pos/(pos+neg)*100)
            print("{} {} {}".format(mean, med, ratio))
            ls = [day, hour, mean, med, ratio]
            df2.loc[n] = ls
            print(df2)
    return df2
df = gather_info(df)
df
# Out:
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.005804336854395409 -0.012978691613263038 48.95833333333333
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  03:00:00 -0.005804 -0.012979  48.958333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.0453861724597641 0.016281367794924506 51.041666666666664
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  04:00:00 -0.045386  0.016281  51.041667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.011244769995954584 0.029936645017613728 53.125
#         weekday  opentime      mean       med   ratio
# 16057  Saturday  05:00:00 -0.011245  0.029937  53.125
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.027866285481933 -0.009138393569145364 46.875
#         weekday  opentime      mean       med   ratio
# 16057  Saturday  06:00:00 -0.027866 -0.009138  46.875
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.14535833512582177 0.07896378908733936 61.458333333333336
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  07:00:00  0.145358  0.078964  61.458333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.030988304538641803 -0.018400235014759403 45.83333333333333
#         weekday  opentime      mean     med      ratio
# 16057  Saturday  08:00:00 -0.030988 -0.0184  45.833333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.038152488186149615 -0.022940404135027848 45.83333333333333
#         weekday  opentime      mean      med      ratio
# 16057  Saturday  09:00:00 -0.038152 -0.02294  45.833333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.04289473787677952 -0.023114540184799637 47.91666666666667
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  10:00:00 -0.042895 -0.023115  47.916667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.0393200182244812 0.018898594634343624 52.083333333333336
#         weekday  opentime     mean       med      ratio
# 16057  Saturday  11:00:00  0.03932  0.018899  52.083333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.03527551000773258 0.0027849000590478568 51.041666666666664
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  12:00:00  0.035276  0.002785  51.041667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.052686834127732375 -0.004544963125660217 50.0
#         weekday  opentime      mean       med  ratio
# 16057  Saturday  13:00:00  0.052687 -0.004545   50.0
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.04872796217287023 0.054146662274824564 57.291666666666664
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  14:00:00  0.048728  0.054147  57.291667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.03259197774984305 0.03316647822624219 52.083333333333336
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  15:00:00  0.032592  0.033166  52.083333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.02128260146064302 -0.012716168192874022 48.95833333333333
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  16:00:00  0.021283 -0.012716  48.958333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.09439075414563784 0.024772024447138108 54.166666666666664
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  17:00:00  0.094391  0.024772  54.166667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.02067222362146337 0.006936405405625123 51.041666666666664
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  18:00:00 -0.020672  0.006936  51.041667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.003102768007381259 0.011880560385456818 53.125
#         weekday  opentime      mean       med   ratio
# 16057  Saturday  19:00:00 -0.003103  0.011881  53.125
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.03237530417406568 0.03272911273572987 56.25
#         weekday  opentime      mean       med  ratio
# 16057  Saturday  20:00:00  0.032375  0.032729  56.25
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.0707992885538462 -0.022032368723138518 47.91666666666667
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  21:00:00 -0.070799 -0.022032  47.916667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.05782230715686006 0.0599699113727965 58.333333333333336
#         weekday  opentime      mean      med      ratio
# 16057  Saturday  22:00:00  0.057822  0.05997  58.333333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.04356274036256602 -0.01531221880216549 44.79166666666667
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  23:00:00 -0.043563 -0.015312  44.791667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.018042701961591412 0.041318018117351585 51.041666666666664
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  00:00:00 -0.018043  0.041318  51.041667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.1135209236693428 0.04688142387674077 53.68421052631579
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  01:00:00  0.113521  0.046881  53.684211
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.07272572037481452 -0.08202220510349889 46.808510638297875
#         weekday  opentime      mean       med      ratio
# 16057  Saturday  02:00:00  0.072726 -0.082022  46.808511
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.034984979374381275 -0.038255520047599134 43.75
#       weekday  opentime      mean       med  ratio
# 16057  Sunday  03:00:00  0.034985 -0.038256  43.75
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.0033105474563788206 0.005267478850626617 50.0
#       weekday  opentime      mean       med  ratio
# 16057  Sunday  04:00:00  0.003311  0.005267   50.0
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.07026580480818352 -0.004523956327233236 50.0
#       weekday  opentime      mean       med  ratio
# 16057  Sunday  05:00:00 -0.070266 -0.004524   50.0
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.05587810652842995 -0.01487824929348136 44.79166666666667
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  06:00:00 -0.055878 -0.014878  44.791667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.03592386565722879 -0.014622880123148718 47.91666666666667
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  07:00:00  0.035924 -0.014623  47.916667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.06252882692075341 0.049973036423054396 53.125
#       weekday  opentime      mean       med   ratio
# 16057  Sunday  08:00:00  0.062529  0.049973  53.125
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.03845367911391554 0.029053573958080392 56.25
#       weekday  opentime      mean       med  ratio
# 16057  Sunday  09:00:00  0.038454  0.029054  56.25
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.06600447919518466 -0.011646937517326705 48.95833333333333
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  10:00:00 -0.066004 -0.011647  48.958333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.06199272331663034 0.011575296535127677 52.083333333333336
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  11:00:00  0.061993  0.011575  52.083333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.08538550009066419 -0.049735617690039646 44.79166666666667
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  12:00:00 -0.085386 -0.049736  44.791667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.17715149249021955 -0.03076063713105981 45.83333333333333
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  13:00:00 -0.177151 -0.030761  45.833333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.0807416771370238 -0.054360883188017795 43.75
#       weekday  opentime      mean       med  ratio
# 16057  Sunday  14:00:00 -0.080742 -0.054361  43.75
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.03072114815117925 -0.010605714369638974 47.91666666666667
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  15:00:00 -0.030721 -0.010606  47.916667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.08959824709322328 -0.017566048889378294 48.95833333333333
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  16:00:00 -0.089598 -0.017566  48.958333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.0071621394543854855 0.06856145096055855 55.208333333333336
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  17:00:00 -0.007162  0.068561  55.208333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.06849510396388458 0.0376252353657236 53.125
#       weekday  opentime      mean       med   ratio
# 16057  Sunday  18:00:00 -0.068495  0.037625  53.125
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.08790682563990959 0.05650663676315304 57.291666666666664
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  19:00:00  0.087907  0.056507  57.291667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.0821569495337336 -0.036865101650860765 38.54166666666667
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  20:00:00 -0.082157 -0.036865  38.541667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.11195864467671661 0.09851241216878037 59.375
#       weekday  opentime      mean       med   ratio
# 16057  Sunday  21:00:00  0.111959  0.098512  59.375
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.19612515367244118 0.014078169564690768 52.083333333333336
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  22:00:00  0.196125  0.014078  52.083333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.015523725157200463 0.10069243595004451 58.333333333333336
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  23:00:00 -0.015524  0.100692  58.333333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.1119373982051209 -0.07432989679799817 42.70833333333333
#       weekday  opentime      mean      med      ratio
# 16057  Sunday  00:00:00 -0.111937 -0.07433  42.708333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.08802665352389102 0.12876390745505262 61.702127659574465
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  01:00:00  0.088027  0.128764  61.702128
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.009426744666172668 0.012805786002985542 50.526315789473685
#       weekday  opentime      mean       med      ratio
# 16057  Sunday  02:00:00 -0.009427  0.012806  50.526316
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.014499086942694068 -0.015329532079249475 46.31578947368421
#       weekday  opentime      mean      med      ratio
# 16057  Monday  03:00:00 -0.014499 -0.01533  46.315789
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.007472132834361315 0.016508649844666934 51.578947368421055
#       weekday  opentime      mean       med      ratio
# 16057  Monday  04:00:00  0.007472  0.016509  51.578947
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.16456301702158085 -0.09383244554641124 41.05263157894737
#       weekday  opentime      mean       med      ratio
# 16057  Monday  05:00:00 -0.164563 -0.093832  41.052632
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.053356355344020376 -0.03431245486629564 46.31578947368421
#       weekday  opentime      mean       med      ratio
# 16057  Monday  06:00:00 -0.053356 -0.034312  46.315789
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.0028109721831448926 0.08344012014663349 61.05263157894737
#       weekday  opentime      mean      med      ratio
# 16057  Monday  07:00:00  0.002811  0.08344  61.052632
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.02212868148038093 0.01381360767864237 51.578947368421055
#       weekday  opentime      mean       med      ratio
# 16057  Monday  08:00:00  0.022129  0.013814  51.578947
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.13235410907299033 0.054529476967886126 55.78947368421052
#       weekday  opentime      mean       med      ratio
# 16057  Monday  09:00:00  0.132354  0.054529  55.789474
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.1584367932020671 -0.04763421294568104 45.26315789473684
#       weekday  opentime      mean       med      ratio
# 16057  Monday  10:00:00 -0.158437 -0.047634  45.263158
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.14821642976356322 0.009882699953635665 52.63157894736842
#       weekday  opentime      mean       med      ratio
# 16057  Monday  11:00:00 -0.148216  0.009883  52.631579
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.0223043627017718 0.007580479423197062 50.526315789473685
#       weekday  opentime      mean      med      ratio
# 16057  Monday  12:00:00  0.022304  0.00758  50.526316
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.3752768302306328 0.17846863384043843 60.0
#       weekday  opentime      mean       med  ratio
# 16057  Monday  13:00:00  0.375277  0.178469   60.0
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.06705592099652605 -0.05684584642230561 47.368421052631575
#       weekday  opentime      mean       med      ratio
# 16057  Monday  14:00:00 -0.067056 -0.056846  47.368421
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.2727522186130373 0.052989615894574627 56.84210526315789
#       weekday  opentime      mean      med      ratio
# 16057  Monday  15:00:00  0.272752  0.05299  56.842105
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.17402301120857738 0.017022907559606892 51.578947368421055
#       weekday  opentime      mean       med      ratio
# 16057  Monday  16:00:00 -0.174023  0.017023  51.578947
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.1401511429654137 0.1326498164589509 63.1578947368421
#       weekday  opentime      mean      med      ratio
# 16057  Monday  17:00:00  0.140151  0.13265  63.157895
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.04359080117293822 -0.037969085074891495 47.368421052631575
#       weekday  opentime      mean       med      ratio
# 16057  Monday  18:00:00 -0.043591 -0.037969  47.368421
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# ...
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.10002638159908095 -0.05903803359149151 42.70833333333333
#       weekday  opentime      mean       med      ratio
# 16057  Friday  05:00:00 -0.100026 -0.059038  42.708333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.12003187521940333 -0.039566779572865585 44.79166666666667
#       weekday  opentime      mean       med      ratio
# 16057  Friday  06:00:00 -0.120032 -0.039567  44.791667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.05598040790566087 0.04406975929307322 54.166666666666664
#       weekday  opentime     mean      med      ratio
# 16057  Friday  07:00:00  0.05598  0.04407  54.166667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.002513298770712602 -0.05745154624553095 47.91666666666667
#       weekday  opentime      mean       med      ratio
# 16057  Friday  08:00:00  0.002513 -0.057452  47.916667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.2257453691670901 -0.02244214316473858 48.95833333333333
#       weekday  opentime      mean       med      ratio
# 16057  Friday  09:00:00  0.225745 -0.022442  48.958333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.1821999224941749 0.10853642449072964 58.333333333333336
#       weekday  opentime    mean       med      ratio
# 16057  Friday  10:00:00  0.1822  0.108536  58.333333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.01545176194939435 0.08825073925500249 58.333333333333336
#       weekday  opentime      mean       med      ratio
# 16057  Friday  11:00:00  0.015452  0.088251  58.333333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.12468968420781164 0.03958615401465693 52.083333333333336
#       weekday  opentime     mean       med      ratio
# 16057  Friday  12:00:00  0.12469  0.039586  52.083333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.010279360278073302 -0.08127609249735457 44.79166666666667
#       weekday  opentime      mean       med      ratio
# 16057  Friday  13:00:00  0.010279 -0.081276  44.791667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.07339414516394956 0.03967499703448851 52.083333333333336
#       weekday  opentime      mean       med      ratio
# 16057  Friday  14:00:00  0.073394  0.039675  52.083333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.0658440166673387 -0.04135948415998314 46.875
#       weekday  opentime      mean       med   ratio
# 16057  Friday  15:00:00 -0.065844 -0.041359  46.875
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.08093154768235289 0.014037022976218338 50.0
#       weekday  opentime      mean       med  ratio
# 16057  Friday  16:00:00 -0.080932  0.014037   50.0
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.08361978194203035 0.1322138072952228 61.458333333333336
#       weekday  opentime     mean       med      ratio
# 16057  Friday  17:00:00  0.08362  0.132214  61.458333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.018026026943991802 -0.016442802282583102 48.95833333333333
#       weekday  opentime      mean       med      ratio
# 16057  Friday  18:00:00 -0.018026 -0.016443  48.958333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.14397450030630488 -0.0695376475354692 39.58333333333333
#       weekday  opentime      mean       med      ratio
# 16057  Friday  19:00:00 -0.143975 -0.069538  39.583333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.11438139934553575 0.05326640916219105 54.166666666666664
#       weekday  opentime      mean       med      ratio
# 16057  Friday  20:00:00  0.114381  0.053266  54.166667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.027122161641356318 0.06043768051887355 58.333333333333336
#       weekday  opentime      mean       med      ratio
# 16057  Friday  21:00:00 -0.027122  0.060438  58.333333
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.11555089148760105 0.025745682154834526 54.166666666666664
#       weekday  opentime      mean       med      ratio
# 16057  Friday  22:00:00  0.115551  0.025746  54.166667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 0.11663501429718333 0.08065001978189912 54.166666666666664
#       weekday  opentime      mean      med      ratio
# 16057  Friday  23:00:00  0.116635  0.08065  54.166667
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.23327314252400155 -0.0316390220342484 46.875
#       weekday  opentime      mean       med   ratio
# 16057  Friday  00:00:00 -0.233273 -0.031639  46.875
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.15647115439386006 -0.05395740845854391 48.421052631578945
#       weekday  opentime      mean       med      ratio
# 16057  Friday  01:00:00 -0.156471 -0.053957  48.421053
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# -0.16125415671551677 -0.18958988382374997 43.61702127659575
#       weekday  opentime      mean      med      ratio
# 16057  Friday  02:00:00 -0.161254 -0.18959  43.617021
#       weekday  opentime      mean      med      ratio
# 16057  Friday  02:00:00 -0.161254 -0.18959  43.617021
