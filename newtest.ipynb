# %%
import pandas as pd

ls = []
for n in range(5):
    ls.append("colonne{}".format(n))
    print(n)
print(ls)
df = pd.DataFrame(columns = ls)
df
ls= ["a", "b", "c", "d", "e"]
y = 0
for item in ls :
    ls2 = []
    for n in range(5):
        x = "{}{}".format(item, n)
        print(x)
        ls2.append(x)
        print(ls2)
    df.loc[y] = ls2
    y +=1
df.index = df.colonne0
df
df.filter(like="c0", axis=0)
# Out:
# 0
# 1
# 2
# 3
# 4
# ['colonne0', 'colonne1', 'colonne2', 'colonne3', 'colonne4']
# a0
# ['a0']
# a1
# ['a0', 'a1']
# a2
# ['a0', 'a1', 'a2']
# a3
# ['a0', 'a1', 'a2', 'a3']
# a4
# ['a0', 'a1', 'a2', 'a3', 'a4']
# b0
# ['b0']
# b1
# ['b0', 'b1']
# b2
# ['b0', 'b1', 'b2']
# b3
# ['b0', 'b1', 'b2', 'b3']
# b4
# ['b0', 'b1', 'b2', 'b3', 'b4']
# c0
# ['c0']
# c1
# ['c0', 'c1']
# c2
# ['c0', 'c1', 'c2']
# c3
# ['c0', 'c1', 'c2', 'c3']
# c4
# ['c0', 'c1', 'c2', 'c3', 'c4']
# d0
# ['d0']
# d1
# ['d0', 'd1']
# d2
# ['d0', 'd1', 'd2']
# d3
# ['d0', 'd1', 'd2', 'd3']
# d4
# ['d0', 'd1', 'd2', 'd3', 'd4']
# e0
# ['e0']
# e1
# ['e0', 'e1']
# e2
# ['e0', 'e1', 'e2']
# e3
# ['e0', 'e1', 'e2', 'e3']
# e4
# ['e0', 'e1', 'e2', 'e3', 'e4']
#          colonne0 colonne1 colonne2 colonne3 colonne4
# colonne0
# c0             c0       c1       c2       c3       c4
